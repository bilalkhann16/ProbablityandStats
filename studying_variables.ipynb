# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
import pandas as pd
url="/home/bilal/Desktop/5thsemister/PROB/stat-env/data/nhanes_2015_2016.csv"
data=pd.read_csv(url)
print (data.head())
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
gender = data['RIAGENDR']
gender.value_counts()
# Out:
# 2    2976
# 1    2759
# Name: RIAGENDR, dtype: int64

# %%
gender.value_counts().plot(kind='bar')
#plt.show()
plt.xticks([0,1],['Male','Female'])
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.show()

# %%
#Most Common Value
sizes = np.array([22, 23, 29, 32, 39, 42, 42, 42, 42, 42, 42, 42, 42, 43, 44, 46, 51, 51, 55, 55, 57, 58, 78, 83, 97, 97])
sizes.mean() #you can't make shirt of 49 since there's no one buying it and you need to find MOST COMMON VALUES
# Out:
# 49.84615384615385

# %%
from collections import Counter
cnt=Counter()
for size in sizes:
    cnt[size]+=1
    #print (cnt)
    
cnt.most_common() #print the shirts with size 42
# Out:
# [(42, 8),
#  (51, 2),
#  (55, 2),
#  (97, 2),
#  (22, 1),
#  (23, 1),
#  (29, 1),
#  (32, 1),
#  (39, 1),
#  (43, 1),
#  (44, 1),
#  (46, 1),
#  (57, 1),
#  (58, 1),
#  (78, 1),
#  (83, 1)]

# %%
from scipy import stats

# %%
data['HIQ210'].unique()
# Out:
# array([ 2., nan,  1.,  9.])

# %%
data['HIQ210'].value_counts().plot(kind='bar')
plt.show()

# %%
data['HIQ210'].value_counts().plot(kind='pie')
plt.show()

# %%
data['BMXWT'].value_counts().plot(kind='bar')
plt.show()

# %%
wt=data['BMXWT']
wt.hist(bins=20)
plt.xlabel('Weight')
plt.ylabel('Frequency')
plt.title("Histogram")

plt.show()

# %%
plt.hist(wt,bins=50)
#plt.grid()
plt.show()

# %%
#Styling Matplotlib with SeaBorn
import seaborn as sns
sns.set(color_codes=True)
sns.set_style("white")

# %%
#histplot known as displot in seaborn
sns.displot(wt,bins=20)
plt.ylabel('Frequency')
plt.xlabel('Weights')
plt.title('Histogram using Seaborn')
sns.despine(offset=5,trim=True)
plt.show()

# %%
#Studying Central Tendency
plt.figure (figsize=(20,5))
x=range(data['BMXWT'].size)
y=data ['BMXWT']

plt.scatter(x,y,marker='x',s=1)
plt.title("Weights of Individuals")
plt.xlabel("Id of Individuals")
plt.ylabel("Weight in Kg")

#ploting the new line
p1=(0,75)
p2=(7000,75)
x_c,y_c=zip(p1,p2)
plt.plot (x_c,y_c,color='red') #can also add width parameter
plt.show()

# %%
wt.mean()
# Out:
# 81.34267560889516

# %%
plt.figure (figsize=(20,5))
x=range(data['BMXWT'].size)
y=data ['BMXWT']

plt.scatter(x,y,marker='x',s=1)
plt.title("Weights of Individuals")
plt.xlabel("Id of Individuals")
plt.ylabel("Weight in Kg")

#ploting the previous line
x_c,y_c=([0,6000],[75,75])
plt.plot (x_c,y_c,color='red') #can also add width parameter
#plt.show()
#new line
plt.plot ([0,6000],[wt.mean(),wt.mean()],color='black') #can also add width parameter
plt.show()

# %%
import numpy as np
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])
#97 is outlier
#this can be solved by replacing the mean to median, median is robust to outliers
#airthmetic mean, mode, median

# %%
np.mean(nums)
# Out:
# 30.625

# %%
#median is solving the problem:
#Quartiles is dividing into 4
#Quantiles is dividing into 4 number, 0.25 is quantile
np.median(nums)
# Out:
# 26.0

# %%
wt.max()
# Out:
# 198.9

# %%
wt.median()
# Out:
# 78.2

# %%
plt.figure (figsize=(20,5))
x= range(data['BMXWT'].size)
y= data['BMXWT']

plt.scatter(x,y,marker='x', s=0.5)

plt.title("Weights Of Individuals")
plt.xlabel("ID of Individuals")
plt.ylabel("Weight(KG)")

x_c,y_c= ([0,6000],[wt.median(),wt.median()])
plt.plot(x_c,y_c,color='red',linewidth=0.75)


x_c,y_c= ([0,6000],[wt.mean(),wt.mean()])
plt.plot(x_c,y_c,color='green',linewidth=2)

plt.show()

# %%
nums = np.array([3, 4, 9, 17, 18, 20, 22, 23, 29, 32, 39, 42, 42, 42, 51, 97])
np.median(nums)
# Out:
# 26.0

# %%
import statistics #use for making quantiles developing

# %%
statistics.quantiles(nums,n=4)
# Out:
# [17.25, 26.0, 42.0]

# %%
statistics.quantiles(wt,n=4)
# Out:
# [43.7, 52.5, 50.1]

# %%
ax=sns.boxplot(x=wt)

# %%
male_wt=data.loc[data['RIAGENDR']==2, 'BMXWT']
print(male_wt)
male_wt.mean()
# Out:
# 3       109.8
# 4        55.2
# 5        64.4
# 7        64.5
# 12       71.2
#         ...
# 5724     58.2
# 5727     64.8
# 5730     59.1
# 5732     71.7
# 5734     58.3
# Name: BMXWT, Length: 2976, dtype: float64
# 76.51676280963693

# %%
f_wt=data.loc[data['RIAGENDR']==1, 'BMXWT']
print(f_wt)
f_wt.mean()
# Out:
# 0        94.8
# 1        90.4
# 2        83.4
# 6        76.6
# 8        72.4
#         ...
# 5726     78.7
# 5728     89.5
# 5729     39.2
# 5731    112.1
# 5733     78.2
# Name: BMXWT, Length: 2759, dtype: float64
# 86.57326222876058

# %%
plt.figure(figsize=(4,8))
sns.set_style('whitegrid')
ax=sns.boxplot(x='RIAGENDR', y='BMXWT',data=data, palette='Set3')
